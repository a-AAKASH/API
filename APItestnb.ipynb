# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/tensorflow-env/lib/python3.9/site-packages/pandas/io/json/_normalize.py:396, in _json_normalize.<locals>._pull_field(js, spec, extract_record)
#     395     else:
# --> 396         result = result[spec]
#     397 except KeyError as e:
#
# KeyError: 'logs'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/aakash/Documents/ALPIMA/API/APItestnb.ipynb Cell 1' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/Users/aakash/Documents/ALPIMA/API/APItestnb.ipynb#ch0000000?line=3'>4</a> with open('data.json','r') as f:
#       <a href='vscode-notebook-cell:/Users/aakash/Documents/ALPIMA/API/APItestnb.ipynb#ch0000000?line=4'>5</a>     data = json.loads(f.read())
# ...
